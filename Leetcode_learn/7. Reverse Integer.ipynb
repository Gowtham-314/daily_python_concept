# %% [markdown]
# ```7. Reverse Integer ```

# %%
class Solution(object):
    def reverse(self, x):
        """
        :type x: int
        :rtype: int
        """
        if -2**31 <= x and x <= (2**31)-1:
            sign = -1 if x < 0 else 1

            num = abs(x)
            rev = 0

            while num > 0:
                last = num % 10
                rev = (rev * 10) + last
                num = num // 10
        
        return rev*sign

# %%
class Solution(object):
    def reverse(self, x):
        """
        :type x: int
        :rtype: int
        """
        if -2**31 <= x and x <= (2**31)-1:
            sign = -1 if x < 0 else 1

            num = abs(x)
            rev = 0

            while num > 0:
                last = num % 10
                rev = (rev * 10) + last
                num = num // 10
            rev *= sign 
            
            return rev  if -2**31 <= rev and rev <= (2**31)-1 else 0

# %%
s = Solution()
s.reverse(123)
# Out:
# 321
