# %% [markdown]
# ## NumPy

# %%
from numpy import *

# %%
arr = array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
# Numpy Array : adding a scalar to a Numpy Array
arr = array([1, 2, 3, 4, 5])
print(arr + 5)
# Out:
# [ 6  7  8  9 10]

# %%
# matrix addition
arr1 = array([[1, 2], [3, 4]])
arr2 = array([[5, 6], [7, 8]])
print(arr1 + arr2)
# Out:
# [[ 6  8]
#  [10 12]]
