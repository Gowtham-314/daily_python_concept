# %% [markdown]
# ## JSON Learning

# %%
import json

# %%
from pprint import pprint

with open("data.json", "r") as file:
    data = json.load(file)
    
    
    pprint(data["products"],width=40)
# Out:
# [{'in_stock': True,
#   'name': 'Matcha',
#   'prcie': 12.99},
#  {'in_stock': False,
#   'name': 'Black Tea',
#   'prcie': 9.99}]

# %%
print(data["products"][0]["name"])
# Out:
# Matcha

# %%
with open("data.json", "r") as file:
    data = json.load(file)
    
for product in data["products"]:
    print(product["sale_price"])
# Out:
# 8.99
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 5
#       2     data = json.load(file)
#       4 for product in data["products"]:
# ----> 5     print(product["sale_price"])
#
# KeyError: 'sale_price'

# %%
with open("data.json", "r") as file:
    data = json.load(file)
    
for product in data["products"]:
    print(product.get("sale_price"))
# Out:
# 8.99
# None

# %%
with open("data.json", "w") as file:
    data = json.load(file)
    data["products"][0].get("sizes").append("extra large")

with open("data.json", "w") as file:
    json.dump(data, file, indent=2)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[57], line 2
#       1 with open("data.json", "w") as file:
# ----> 2     data = json.load(file)
#       3     data["products"][0].get("sizes").append("extra large")
#       5 with open("data.json", "w") as file:
#
# File c:\Users\gowda\anaconda3\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# UnsupportedOperation: not readable
