# %%
from PIL import Image
from pathlib import Path

file = Path.cwd().parent / "qrcode"

# %%
# Open the image file
img = Image.open(file/"email.png")
img.show()

# %%
img = Image.open(f"{file}/email.png")
img.show()

# %%
# Image info
print(img.format)
print(img.size)
print(img.mode)
# Out:
# PNG
# (370, 370)
# 1

# %%
# Create a Image

img = Image.new("RGB", (500, 500), "blue")
img.show()
img.save("output.png")

# %%
# Resize the image
resized = img.resize((300, 300))
resized.show()
