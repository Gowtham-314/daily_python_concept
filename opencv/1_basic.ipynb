# %% [markdown]
# ```OpenCV in Python (cv2)```

# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.13.0

# %%
# Read an image

img = cv2.imread("C:/Users/gowda/OneDrive/Desktop/Python/Daily_Python_Concept/opencv/cat.png")
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("cat.png", cv2.IMREAD_UNCHANGED)
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("new_image.jpg", img)
