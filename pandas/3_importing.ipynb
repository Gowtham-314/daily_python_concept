# %%
# importing the file to work with pandas

import pandas as pd

# %%
df = pd.read_csv('data_sets/bank.csv')
print(df)
# Out:
#      age           job   marital  education  balance housing loan
# 0     58    management   married   tertiary     2143     yes   no
# 1     44    technician    single  secondary       29     yes   no
# 2     33  entrepreneur   married  secondary        2     yes  yes
# 3     47   blue-collar   married    unknown     1506     yes   no
# 4     33       unknown    single    unknown        1      no   no
# ..   ...           ...       ...        ...      ...     ...  ...
# 144   59   blue-collar   married  secondary       57     yes   no
# 145   33      services   married  secondary       22     yes   no
# 146   56   blue-collar  divorced    primary        8     yes   no
# 147   48    unemployed   married  secondary      293     yes   no
# 148   43      services   married    primary        3     yes   no
#
# [149 rows x 7 columns]

# %%
print(df.to_string())
# Out:
#      age            job   marital  education  balance housing loan
# 0     58     management   married   tertiary     2143     yes   no
# 1     44     technician    single  secondary       29     yes   no
# 2     33   entrepreneur   married  secondary        2     yes  yes
# 3     47    blue-collar   married    unknown     1506     yes   no
# 4     33        unknown    single    unknown        1      no   no
# 5     35     management   married   tertiary      231     yes   no
# 6     28     management    single   tertiary      447     yes  yes
# 7     42   entrepreneur  divorced   tertiary        2     yes   no
# 8     58        retired   married    primary      121     yes   no
# 9     43     technician    single  secondary      593     yes   no
# 10    41         admin.  divorced  secondary      270     yes   no
# 11    29         admin.    single  secondary      390     yes   no
# 12    53     technician   married  secondary        6     yes   no
# ...

# %%
df = pd.read_json('data_sets/students.json')

print(df.to_string())
# Out:
#     _id          auid         usn             name                             email  gender        mentor  roll
# 0     1  MEG26BEAI201  1MG26AI001     AARAV SHETTY         aaravs_26beai@megan.ac.in    Male   Dr. Meera N     1
# 1     2  MEG26BEAI202  1MG26AI002        ANIKA RAO         anikar_26beai@megan.ac.in  Female   Dr. Meera N     2
# 2     3  MEG26BEAI203  1MG26AI003     BHARAT KUMAR        bharatk_26beai@megan.ac.in    Male  Dr. Krishnan     3
# 3     4  MEG26BEAI204  1MG26AI004      CHARULATA M      charulata_26beai@megan.ac.in  Female   Dr. Meera N     4
# 4     5  MEG26BEAI205  1MG26AI005        DEVANSH P       devanshp_26beai@megan.ac.in    Male  Dr. Krishnan     5
# 5     6  MEG26BEAI206  1MG26AI006          EESHA V         eeshav_26beai@megan.ac.in  Female   Dr. Meera N     6
# 6     7  MEG26BEAI207  1MG26AI007     FARHAN AHMED        farhana_26beai@megan.ac.in    Male  Dr. Krishnan     7
# ...
